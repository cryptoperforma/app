# %%
# Install required packages
# !pip install -q torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# !pip install -q diffusers transformers accelerate ftfy

# Import necessary libraries
import os
import numpy as np
import torch
from PIL import Image, ImageFilter, ImageDraw
from diffusers import StableDiffusionImg2ImgPipeline
from google.colab import auth, drive

# Authenticate and mount Google Drive
auth.authenticate_user()
drive.mount('/content/drive', force_remount=True)

# Define input/output directories
INPUT_DIR = '/content/drive/My Drive/input-logos'
OUTPUT_DIR = '/content/drive/My Drive/output-logos'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Initialize Stable Diffusion pipeline
device = "cuda" if torch.cuda.is_available() else "cpu"
model_id = "stabilityai/stable-diffusion-2-1"

pipe = StableDiffusionImg2ImgPipeline.from_pretrained(
    model_id,
    revision="fp16",
    torch_dtype=torch.float16,
    use_auth_token=True
).to(device)

# Aesthetic template with enhanced prompts
AESTHETIC_TEMPLATE = """
Minimalist geometric logo design with {points} key elements,
flat vector style, clean lines, symmetrical composition,
vibrant colors on neutral background, professional corporate identity
"""

def generate_logo_variations(input_path, output_dir, num_variations=4):
    try:
        # Load and prepare base image
        init_image = Image.open(input_path).convert("RGB")
        init_image = init_image.resize((768, 768))
        filename = os.path.splitext(os.path.basename(input_path))[0]

        for i in range(num_variations):
            try:
                # Generate parameters
                points = int(np.random.choice([3, 4, 5]))  # Convert to native int
                prompt = AESTHETIC_TEMPLATE.format(points=points)
                strength = np.random.uniform(0.3, 0.6)
                guidance = np.random.uniform(7.5, 15.0)

                # Generate image
                result = pipe(
                    prompt=prompt,
                    negative_prompt="text, watermark, low quality, blurry, messy, noisy",
                    image=init_image,
                    strength=strength,
                    guidance_scale=guidance,
                    num_inference_steps=50
                ).images[0]

                # Save result
                output_path = os.path.join(output_dir, f'{filename}_variation_{i+1}.png')
                result.save(output_path)
                print(f'Saved variation {i+1} to {output_path}')

            except Exception as gen_error:
                print(f'Error generating variation {i+1}: {str(gen_error)}')
                continue

    except Exception as e:
        print(f'Error processing file {input_path}: {str(e)}')

# Process all logos
for filename in os.listdir(INPUT_DIR):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        input_path = os.path.join(INPUT_DIR, filename)
        try:
            print(f'Processing {filename}...')
            generate_logo_variations(input_path, OUTPUT_DIR)
        except Exception as e:
            print(f'Fatal error processing {filename}: {str(e)}')
            continue

print('Processing completed!')
# Out:
# Mounted at /content/drive
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionImg2ImgPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-2-1/snapshots/f7f33030acc57428be85fbec092c37a78231d75a/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-2-1/snapshots/f7f33030acc57428be85fbec092c37a78231d75a/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-2-1/snapshots/f7f33030acc57428be85fbec092c37a78231d75a/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-2-1/snapshots/f7f33030acc57428be85fbec092c37a78231d75a/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Processing preferencil.png...
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/preferencil_variation_1.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/preferencil_variation_2.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/preferencil_variation_3.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/preferencil_variation_4.png
# Processing cryptoperfoma.png...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/cryptoperfoma_variation_1.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/cryptoperfoma_variation_2.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/cryptoperfoma_variation_3.png
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/cryptoperfoma_variation_4.png
# Processing waytogoasis.png...
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/waytogoasis_variation_1.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/waytogoasis_variation_2.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/waytogoasis_variation_3.png
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/waytogoasis_variation_4.png
# Processing crossmodais.png...
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/crossmodais_variation_1.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/crossmodais_variation_2.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/crossmodais_variation_3.png
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/crossmodais_variation_4.png
# Processing nomelhorsentido.png...
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/nomelhorsentido_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/nomelhorsentido_variation_2.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/nomelhorsentido_variation_3.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/nomelhorsentido_variation_4.png
# Processing kr4ser.png...
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/kr4ser_variation_1.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/kr4ser_variation_2.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/kr4ser_variation_3.png
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/kr4ser_variation_4.png
# Processing hot4xp.png...
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/hot4xp_variation_1.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/hot4xp_variation_2.png
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/hot4xp_variation_3.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/hot4xp_variation_4.png
# Processing modelos generativos - inverter onda.png...
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_1.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_2.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_3.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_4.png
# Processing md4moe.png...
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/md4moe_variation_1.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/md4moe_variation_2.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/md4moe_variation_3.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/md4moe_variation_4.png
# Processing casset.png...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/casset_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/casset_variation_2.png
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/casset_variation_3.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/casset_variation_4.png
# Processing promptprotocol.png...
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/promptprotocol_variation_1.png
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/promptprotocol_variation_2.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/promptprotocol_variation_3.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/promptprotocol_variation_4.png
# Processing up4dca.png...
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/up4dca_variation_1.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/up4dca_variation_2.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/up4dca_variation_3.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/up4dca_variation_4.png
# Processing hot4fd.png...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/hot4fd_variation_1.png
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/hot4fd_variation_2.png
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/hot4fd_variation_3.png
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/hot4fd_variation_4.png
# Processing moe4xp.png...
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/moe4xp_variation_1.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/moe4xp_variation_2.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/moe4xp_variation_3.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/moe4xp_variation_4.png
# Processing crossindex.png...
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/crossindex_variation_1.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/crossindex_variation_2.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/crossindex_variation_3.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/crossindex_variation_4.png
# Processing 3 pixels laranjas proximos do natural.png...
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_2.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_3.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_4.png
# Processing crossmodaldebate.png...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/crossmodaldebate_variation_1.png
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/crossmodaldebate_variation_2.png
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/crossmodaldebate_variation_3.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/crossmodaldebate_variation_4.png
# Processing metateca.png...
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/metateca_variation_1.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/metateca_variation_2.png
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/metateca_variation_3.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/metateca_variation_4.png
# Processing florescenciacanabica - flores de bem-me-quer-, maracuja e camomila.png...
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_2.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_3.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_4.png
# Processing estaraverse.png...
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/estaraverse_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/estaraverse_variation_2.png
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/estaraverse_variation_3.png
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/estaraverse_variation_4.png
# Processing tagdebate-laranja e lilas.png...
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_1.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_2.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_3.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_4.png
# Processing saneagent.png...
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/saneagent_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/saneagent_variation_2.png
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/saneagent_variation_3.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/saneagent_variation_4.png
# Processing mixritual.png...
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/mixritual_variation_1.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/mixritual_variation_2.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/mixritual_variation_3.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/mixritual_variation_4.png
# Processing tagagentic.png...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/tagagentic_variation_1.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/tagagentic_variation_2.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/tagagentic_variation_3.png
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/tagagentic_variation_4.png
# Processing psicofisicacanabica .png...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/psicofisicacanabica _variation_1.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/psicofisicacanabica _variation_2.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/psicofisicacanabica _variation_3.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/psicofisicacanabica _variation_4.png
# Processing agentescrossmodais.png...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/agentescrossmodais_variation_1.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/agentescrossmodais_variation_2.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/agentescrossmodais_variation_3.png
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/agentescrossmodais_variation_4.png
# Processing sutiliza.png...
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/sutiliza_variation_1.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/sutiliza_variation_2.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/sutiliza_variation_3.png
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/sutiliza_variation_4.png
# Processing hot4dp.png...
#   0%|          | 0/26 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/hot4dp_variation_1.png
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/hot4dp_variation_2.png
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/hot4dp_variation_3.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/hot4dp_variation_4.png
# Processing crossmodalritual.png...
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/crossmodalritual_variation_1.png
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/crossmodalritual_variation_2.png
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/crossmodalritual_variation_3.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/crossmodalritual_variation_4.png
# Processing sanoexplorar.png...
#   0%|          | 0/19 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/sanoexplorar_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/sanoexplorar_variation_2.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/sanoexplorar_variation_3.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/sanoexplorar_variation_4.png
# Processing emcomitiva.png...
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/emcomitiva_variation_1.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/emcomitiva_variation_2.png
#   0%|          | 0/17 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/emcomitiva_variation_3.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/emcomitiva_variation_4.png
# Processing zk4cfm.png...
#   0%|          | 0/15 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/zk4cfm_variation_1.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/zk4cfm_variation_2.png
#   0%|          | 0/28 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/zk4cfm_variation_3.png
#   0%|          | 0/29 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/zk4cfm_variation_4.png
# Processing agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo.png...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_1.png
#   0%|          | 0/20 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_2.png
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_3.png
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_4.png
# Processing gendeeper_branch.png...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/gendeeper_branch_variation_1.png
#   0%|          | 0/21 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/gendeeper_branch_variation_2.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/gendeeper_branch_variation_3.png
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/gendeeper_branch_variation_4.png
# Processing ensisanar.png...
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/ensisanar_variation_1.png
#   0%|          | 0/22 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/ensisanar_variation_2.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/ensisanar_variation_3.png
#   0%|          | 0/18 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/ensisanar_variation_4.png
# Processing emodiversa - cortar coracao, 90graus base.png...
#   0%|          | 0/23 [00:00<?, ?it/s]
# Saved variation 1 to /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_1.png
#   0%|          | 0/24 [00:00<?, ?it/s]
# Saved variation 2 to /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_2.png
#   0%|          | 0/27 [00:00<?, ?it/s]
# Saved variation 3 to /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_3.png
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved variation 4 to /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_4.png
# Processing completed!
